# %% [markdown]
# <a href="https://colab.research.google.com/github/sampada2408/Heart_Disease_Prediction/blob/main/Heart_Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing Dependencies***

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ***Data Preprocessing and analysis***

# %%
heart_data= pd.read_csv("/content/heart.csv", header=0)

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_data.shape
# Out:
# (1025, 14)

# %%
heart_data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heart_data.value_counts('target')
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# 1--> Defective Heart || 0--> Healthy heart

# %% [markdown]
# ***Splitting the features from the target column and removing irrelavent column***

# %%
X= heart_data.drop(columns=['target'], axis=1)
Y= heart_data['target']

# %% [markdown]
# ***Splitting the data into train and test***

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %% [markdown]
# ***Model Training***

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ***Training data accuracy***

# %%
Y_test_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test,Y_test_pred)
print(f"Accuracy on test data: {accuracy:.4f}")
# Out:
# Accuracy on test data: 1.0000

# %% [markdown]
# ***Classification Report***

# %%
print("\nClassification Report:")
print(classification_report(Y_test, Y_test_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       105
#
#     accuracy                           1.00       205
#    macro avg       1.00      1.00      1.00       205
# weighted avg       1.00      1.00      1.00       205

# %% [markdown]
# ***Confusion Matrix***

# %%
print("Confusion Matrix:")
print(confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix:
# [[100   0]
#  [  0 105]]

# %% [markdown]
# ***Cross Val Score***

# %%
cross_val=cross_val_score(model, X, Y, cv=5)
print("cross validation score:",np.mean(cross_val))
# Out:
# cross validation score: 0.9970731707317073

# %% [markdown]
# ***Inputting the data***

# %%
def parkinsons_prediction_model(input_data):
    input_data_as_numpy_array = np.asarray(input_data)
    input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)
    input_df = pd.DataFrame(input_data_reshaped, columns=X.columns)

    prediction = model.predict(input_df)

    if prediction[0] == 0:
        print('The person is healthy')
    else:
        print('The person has Heart Disease')


test_data = (51,1,3,125,213,0,0,125,1,1.4,2,1,2)
parkinsons_prediction_model(test_data)
# Out:
# The person has Heart Disease
